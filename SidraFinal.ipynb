# %%
#valores para montar a base de tabelas/classificacoes/categorias/variaveis

import requests
import pandas as pd

response = requests.get('https://servicodados.ibge.gov.br/api/v3/agregados')

if response.status_code == 200:
    data = response.json()

# lista de tabelas

    data_list = []

    for item in data:
        id = item['id']
        pesquisa = item['nome']
        for agregado in item['agregados']:
            id_df = agregado['id']
            nome_df = agregado['nome']
            data_list.append([id, pesquisa, id_df, nome_df])
            if 'SU' == item['id'] : df_lista = pd.DataFrame(data_list, columns=['id_lista')


#base de tabelas/classificacoes/categorias/variaveis

for tab in df_lista

tabela = '2093'

endereco = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+tabela+'/metadados'

response = requests.get(endereco)

if response.status_code == 200:
    data = response.json()

#Catgoria x classificacao

df_categ = pd.json_normalize(data,
    record_path=['classificacoes','categorias'],
    meta=["id"],#["classificacoes","id"],["classificacoes","nome"]],
    meta_prefix='tabela_',
    record_prefix='categ_'
    )

#Variaveis x classificacao

df_var = pd.json_normalize(data,
    record_path=['variaveis'],
    meta=["id","nome","URL","pesquisa","assunto",["periodicidade","frequencia"],["periodicidade","inicio"],["periodicidade","fim"],["nivelTerritorial","Administrativo"]],
    meta_prefix='Tabela_',
    record_prefix='var_'
    )

if df_categ.empty:
    df = df_var
else:
    df = df_categ.merge(df_var, left_on='tabela_id',right_on='Tabela_id')

#df["N1"]=(df["Tabela_nivelTerritorial.Administrativo"])
         
#if 'N1' in df["Tabela_nivelTerritorial.Administrativo"]:
#    df["N1"]="1"
#else:
#    df["N1"]="0"
# [N15, N1, N2, N8, N9, N6, N14, N7, N13, N3]
print(df)

#2093 tem + de 1 classificações e categorias
# Out:
#   Cell In[2], line 22
#     if 'SU' == item['id'] : df_lista = pd.DataFrame(data_list, columns=['id_lista')
#                                                                                   ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
#valores para montar a base de tabelas/classificacoes/categorias/variaveis

#https://apisidra.ibge.gov.br/values/t/1621/n1/all/v/all/p/last%201/c11255/90687/d/v584%202

#https://apisidra.ibge.gov.br/values/t/1621/n1/all/v/all/p/last%201/c11255/90687/d/v584%202

#https://servicodados.ibge.gov.br/api/v3/agregados/2093/metadados

import requests
import pandas as pd

tabela = '6784'
endereco = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+tabela+'/metadados'

response = requests.get(endereco)

if response.status_code == 200:
    data = response.json()

#Catgoria x classificacao

df_categ = pd.json_normalize(data,
    record_path=['classificacoes','categorias'],
    meta=["id",["classificacoes","id"],["classificacoes","nome"]],
    meta_prefix='tabela_'
    )

#Variaveis x classificacao

df_var = pd.json_normalize(data,
    record_path=['variaveis'],
    meta=["id","nome","URL","pesquisa","assunto",["periodicidade","frequencia"],["periodicidade","inicio"],["periodicidade","fim"],["nivelTerritorial","Administrativo"]],
    meta_prefix='Tabela_')

df = df_categ.merge(df_var, left_on='tabela_id',right_on='Tabela_id',suffixes=('_categ', '_var'))

print(df_var)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2016\3077420793.py in ?()
#      31     record_path=['variaveis'],
#      32     meta=["id","nome","URL","pesquisa","assunto",["periodicidade","frequencia"],["periodicidade","inicio"],["periodicidade","fim"],["nivelTerritorial","Administrativo"]],
#      33     meta_prefix='Tabela_')
#      34
# ---> 35 df = df_categ.merge(df_var, left_on='tabela_id',right_on='Tabela_id',suffixes=('_categ', '_var'))
#      36
#      37 print(df_var)
#
# c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10815         validate: MergeValidate | None = None,
#   10816     ) -> DataFrame:
#   10817         from pandas.core.reshape.merge import merge
#   10818
# > 10819         return merge(
#   10820             self,
#   10821             right,
#   10822             how=how,
#
# c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1306                     if lk is not None:
#    1307                         # Then we're either Hashable or a wrong-length arraylike,
#    1308                         #  the latter of which will raise
#    1309                         lk = cast(Hashable, lk)
# -> 1310                         left_keys.append(left._get_label_or_level_values(lk))
#    1311                         join_names.append(lk)
#    1312                     else:
#    1313                         # work-around for merge_asof(left_index=True)
#
# c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1906             values = self.xs(key, axis=other_axes[0])._values
#    1907         elif self._is_level_reference(key, axis=axis):
#    1908             values = self.axes[axis].get_level_values(key)._values
#    1909         else:
# -> 1910             raise KeyError(key)
#    1911
#    1912         # Check for duplicates
#    1913         if values.ndim > 1:
#
# KeyError: 'tabela_id'

# %%
#valores para a API

#https://apisidra.ibge.gov.br/values/t/1621/n1/all/v/all/p/last%201/c11255/90687/d/v584%202

#https://apisidra.ibge.gov.br/values/t/1621/n1/all/v/all/p/last%201/c11255/90687/d/v584%202

#https://servicodados.ibge.gov.br/api/v3/agregados/2093/metadados

import requests
import pandas as pd

tabela = '2093'
variavel = '93'
classificacao = '86'
categoria ='2776'
nivel = 'n1/all'

#if N6 == 1:
#    nivel = 'n1/all/n6/in n3 33'
#else:
#    if N3 ==1: 
#        nivel = 'n1/all/n3/all'
#   else: nivel = 'n1/all'

endereco = 'https://apisidra.ibge.gov.br/values/t/'+tabela+'/'+nivel+'/v/'+variavel+'/p/all/c'+classificacao+'/'+categoria+'/h/n'

response = requests.get(endereco)

if response.status_code == 200:
    data = response.json()

df = pd.DataFrame(data)
df
# Out:
#   NC      NN  MC       MN         V D1C     D1N D2C                  D2N  \
# 0  1  Brasil  45  Pessoas  91298042   1  Brasil  93  População residente
# 1  1  Brasil  45  Pessoas  90621281   1  Brasil  93  População residente
#
#     D3C   D3N   D4C     D4N D5C    D5N D6C    D6N D7C    D7N
# 0  2000  2000  2776  Branca   0  Total   0  Total   0  Total
# 1  2010  2010  2776  Branca   0  Total   0  Total   0  Total
