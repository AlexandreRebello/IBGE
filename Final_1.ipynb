# %%
#lista de parametros para API

import requests
import pandas as pd
import numpy as np
import time

response = requests.get('https://servicodados.ibge.gov.br/api/v3/agregados?nivel=N6')

if response.status_code == 200:
    data = response.json()

    resultado = pd.DataFrame({'categ_id':str([]), 'categ_nome':[], 'categ_unidade':[], 'categ_nivel':[], 'tabela_id':str([]),
       'tabela_classificacoes.id':[], 'tabela_classificacoes.nome':[],                      
       'var_id':str([]), 'var_nome':[], 'var_unidade':[], 'var_sumarizacao':[], 'tabela_id':str([]),
       'Tabela_nome':[], 'Tabela_URL':[], 'Tabela_pesquisa':[], 'Tabela_assunto':[],
       'Tabela_periodicidade.frequencia':[], 'Tabela_periodicidade.inicio':[],
       'Tabela_periodicidade.fim':[], 'Tabela_nivelTerritorial.Administrativo':[]})
    
    data_list = []

    for item in data:
        id = item['id']
        pesquisa = item['nome']
        for agregado in item['agregados']:
            tabela = agregado['id']
            nome_tabela = agregado['nome']
            data_list.append([id, pesquisa, tabela, nome_tabela])
            df = pd.DataFrame(data_list, columns=['id', 'pesquisa', 'tabela', 'nome_tabela'])
    #lista = df['tabela']

    lista = pd.DataFrame({'tabela':['6784','1621','2093']})
    print(lista)
    for item in lista['tabela']:
    #for item in lista:
        tab = item
        #print(IdTabela)
        enderecoT = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+tab+'/metadados'
        print(enderecoT)
        responseT = requests.get(enderecoT)
        dataT = responseT.json()
        #print(dataT)
        df_categ = pd.json_normalize(dataT,
            record_path=['classificacoes','categorias'],
            meta=["id",["classificacoes","id"],["classificacoes","nome"]],
            meta_prefix='tabela_',
            record_prefix='categ_',
            errors='ignore'
            )
        df_categ.to_csv("teste_categ4.csv",mode='a',header=False)
        #print(df_categ)
                #Variaveis x classificacao

        df_var = pd.json_normalize(dataT,
            record_path=['variaveis'],
            meta=["id"],
            meta_prefix='tabela_',
            record_prefix='var_',
            errors='ignore'
            )
        df_var.to_csv("teste_var4.csv",mode='a',header=False)

        df_tab = pd.json_normalize(dataT,
                                   
            meta=["id","nome","URL","pesquisa","assunto",["nivelTerritorial","Administrativo"]],
            meta_prefix='tabela_',
            record_prefix='var_',
            errors='ignore'
            )
        df_tab = df_tab.loc[:,['id','nome','URL','pesquisa','assunto','periodicidade.frequencia','periodicidade.inicio','periodicidade.fim']]

        df_tab.to_csv("teste_tab4.csv",mode='a',header=False)

        # if df_categ.empty:
        #     dfm = df_var
        # else:
        #     dfm = df_categ.merge(df_var, left_on='tabela_id',right_on='tabela_id')

        # print(dfm)
        # #print("muda/muda/muda")
        # resultado = pd.concat([resultado,dfm])
        # resultado = resultado.loc[:,[str('tabela_id'),str('var_id'),str('tabela_classificacoes.id'),str('categ_id')]]
        
        #print(resultado)
        #time.sleep(10)

    # print("RESULTADO/RESULTADO/RESULTADO")    
    # #print(resultado.dtypes)
    # resultado.to_csv("teste_res2.csv",mode='a',header=False)
    # print(resultado)
else:
    print(f"Request failed with status code {response.status_code}")
# Out:
#   tabela
# 0   6784
# 1   1621
# 2   2093
# https://servicodados.ibge.gov.br/api/v3/agregados/6784/metadados
# https://servicodados.ibge.gov.br/api/v3/agregados/1621/metadados
# https://servicodados.ibge.gov.br/api/v3/agregados/2093/metadados

# %%
#lista de parametros para API

import requests
import pandas as pd
import numpy as np
import time

response = requests.get('https://servicodados.ibge.gov.br/api/v3/agregados?nivel=N6')

if response.status_code == 200:
    data = response.json()

    resultado = pd.DataFrame({'categ_id':str([]), 'categ_nome':[], 'categ_unidade':[], 'categ_nivel':[], 'tabela_id':str([]),
       'tabela_classificacoes.id':[], 'tabela_classificacoes.nome':[],                      
       'var_id':str([]), 'var_nome':[], 'var_unidade':[], 'var_sumarizacao':[], 'tabela_id':str([]),
       'Tabela_nome':[], 'Tabela_URL':[], 'Tabela_pesquisa':[], 'Tabela_assunto':[],
       'Tabela_periodicidade.frequencia':[], 'Tabela_periodicidade.inicio':[],
       'Tabela_periodicidade.fim':[], 'Tabela_nivelTerritorial.Administrativo':[]})
    
    data_list = []

    for item in data:
        id = item['id']
        pesquisa = item['nome']
        for agregado in item['agregados']:
            tabela = agregado['id']
            nome_tabela = agregado['nome']
            data_list.append([id, pesquisa, tabela, nome_tabela])
            df = pd.DataFrame(data_list, columns=['id', 'pesquisa', 'tabela', 'nome_tabela'])
    lista = df['tabela']

    #lista = pd.DataFrame({'tabela':['6784','1621','2093']})
    print(lista)
    #for item in lista['tabela']:
    for item in lista:
        tab = item
        #print(IdTabela)
        enderecoT = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+tab+'/metadados'
        print(enderecoT)
        
        segue = 0
        response = requests.get(enderecoT)
        segue = response.status_code
        print(segue)
        while segue != 200:
            response = requests.get(enderecoT)
            segue = response.status_code
            print(segue)
            print("ERRO")
            #time.sleep(2)
        # else:
        dataT = response.json()
        
        print("PASSOU")
        #print(dataT)

        #print(dataT)
        # df_categ = pd.json_normalize(dataT,
        #     record_path=['classificacoes','categorias'],
        #     meta=["id",["classificacoes","id"],["classificacoes","nome"]],
        #     meta_prefix='tabela_',
        #     record_prefix='categ_',
        #     errors='ignore'
        #     )
        # df_categ.to_csv("teste_categ5.csv",mode='a',header=False)
        # #print(df_categ)
        #         #Variaveis x classificacao

        # df_var = pd.json_normalize(dataT,
        #     record_path=['variaveis'],
        #     meta=["id"],
        #     meta_prefix='tabela_',
        #     record_prefix='var_',
        #     errors='ignore'
        #     )
        # df_var.to_csv("teste_var5.csv",mode='a',header=False)

        df_tab = pd.json_normalize(dataT,
                                   
            meta=["id","nome","URL","pesquisa","assunto"],#["nivelTerritorial","Administrativo"]],
            meta_prefix='tabela_',
            record_prefix='var_',
            errors='ignore'
            )
        #df_tab = df_tab.loc[:,['id','nome','URL','pesquisa','assunto','periodicidade.frequencia','periodicidade.inicio','periodicidade.fim']]

        df_tab.to_csv("teste_tab8.csv",mode='a',sep=';', na_rep='',columns=['id','nome','URL','pesquisa','assunto','periodicidade.frequencia','periodicidade.inicio','periodicidade.fim'],header=False,index=False)
        
        #time.sleep(30)
        
else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# 0       8418
# 1       1685
# 2       1734
# 3       1735
# 4       2933
#         ...
# 4016     291
# 4017     292
# 4018    5930
# 4019      21
# 4020    5938
# Name: tabela, Length: 4021, dtype: object
# https://servicodados.ibge.gov.br/api/v3/agregados/8418/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1685/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1734/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1735/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/2933/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/3421/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/6449/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/6450/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/993/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1005/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1006/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1008/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1009/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1010/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1011/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1012/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1013/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1014/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1015/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1016/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1017/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1018/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1019/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1020/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1021/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1022/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1025/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1031/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1097/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1098/metadados
# 500
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1099/metadados
# 500
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1101/metadados
# 500
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1109/metadados
# 500
# 500
# ERRO
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1110/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1111/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1112/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1113/metadados
# 500
# 500
# ERRO
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1114/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1115/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1116/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1117/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1118/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1119/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1120/metadados
# 500
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1177/metadados
# 500
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1178/metadados
# 500
# 500
# ERRO
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1179/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1181/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1224/metadados
# 500
# 500
# ERRO
# 500
# ERRO
# 500
# ERRO
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1225/metadados
# 500
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1226/metadados
# 500
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1227/metadados
# 500
# 500
# ERRO
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1244/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1245/metadados
# 500
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1246/metadados
# 500
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1249/metadados
# 500
# 500
# ERRO
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1258/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1259/metadados
# 500
# 500
# ERRO
# 500
# ERRO
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1260/metadados
# 500
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1261/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1262/metadados
# 500
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1267/metadados
# 500
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1268/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1269/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1270/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1271/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1272/metadados
# 500
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1273/metadados
# 500
# 500
# ERRO
# 500
# ERRO
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1274/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1275/metadados
# 500
# 500
# ERRO
# 500
# ERRO
# 500
# ERRO
# 200
# ERRO
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1276/metadados
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 42
#      39 print(enderecoT)
#      41 segue = 0
# ---> 42 response = requests.get(enderecoT)
#      43 segue = response.status_code
#      44 print(segue)
#
# File c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1390, in HTTPConnection.getresponse(self)
#    1388 try:
#    1389     try:
# -> 1390         response.begin()
#    1391     except ConnectionError:
#    1392         self.close()
#
# File c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\http\client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\http\client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#lista de parametros para API

import requests
import pandas as pd
import numpy as np
import time

response = requests.get('https://servicodados.ibge.gov.br/api/v3/agregados?nivel=N6')

if response.status_code == 200:
    data = response.json()

    resultado = pd.DataFrame({'categ_id':str([]), 'categ_nome':[], 'categ_unidade':[], 'categ_nivel':[], 'tabela_id':str([]),
       'tabela_classificacoes.id':[], 'tabela_classificacoes.nome':[],                      
       'var_id':str([]), 'var_nome':[], 'var_unidade':[], 'var_sumarizacao':[], 'tabela_id':str([]),
       'Tabela_nome':[], 'Tabela_URL':[], 'Tabela_pesquisa':[], 'Tabela_assunto':[],
       'Tabela_periodicidade.frequencia':[], 'Tabela_periodicidade.inicio':[],
       'Tabela_periodicidade.fim':[], 'Tabela_nivelTerritorial.Administrativo':[]})
    
    data_list = []

    for item in data:
        id = item['id']
        pesquisa = item['nome']
        for agregado in item['agregados']:
            tabela = agregado['id']
            nome_tabela = agregado['nome']
            data_list.append([id, pesquisa, tabela, nome_tabela])
            df = pd.DataFrame(data_list, columns=['id', 'pesquisa', 'tabela', 'nome_tabela'])
    lista = df['tabela']

    #lista = pd.DataFrame({'tabela':['6784','1621','2093']})
    print(lista)
    #for item in lista['tabela']:
    for item in lista:
        tab = item
        #print(IdTabela)
        enderecoT = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+tab+'/metadados'
        print(enderecoT)
        response = requests.get(enderecoT)
        dataT = response.json()
        print(response)
        

        #print(dataT)
        # df_categ = pd.json_normalize(dataT,
        #     record_path=['classificacoes','categorias'],
        #     meta=["id",["classificacoes","id"],["classificacoes","nome"]],
        #     meta_prefix='tabela_',
        #     record_prefix='categ_',
        #     errors='ignore'
        #     )
        # df_categ.to_csv("teste_categ5.csv",mode='a',header=False)
        # #print(df_categ)
        #         #Variaveis x classificacao

        # df_var = pd.json_normalize(dataT,
        #     record_path=['variaveis'],
        #     meta=["id"],
        #     meta_prefix='tabela_',
        #     record_prefix='var_',
        #     errors='ignore'
        #     )
        # df_var.to_csv("teste_var5.csv",mode='a',header=False)

        df_tab = pd.json_normalize(dataT,
                                   
            meta=["id","nome","URL","pesquisa","assunto"],#["nivelTerritorial","Administrativo"]],
            meta_prefix='tabela_',
            record_prefix='var_',
            errors='ignore'
            )
        #df_tab = df_tab.loc[:,['id','nome','URL','pesquisa','assunto','periodicidade.frequencia','periodicidade.inicio','periodicidade.fim']]

        df_tab.to_csv("teste_tab7.csv",mode='a',sep=';', na_rep='',columns=['id','nome','URL','pesquisa','assunto','periodicidade.frequencia','periodicidade.inicio','periodicidade.fim'],header=False,index=False)
        
        #time.sleep(30)
        
else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# 0       8418
# 1       1685
# 2       1734
# 3       1735
# 4       2933
#         ...
# 4016     291
# 4017     292
# 4018    5930
# 4019      21
# 4020    5938
# Name: tabela, Length: 4021, dtype: object
# https://servicodados.ibge.gov.br/api/v3/agregados/8418/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1685/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1734/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1735/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/2933/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/3421/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/6449/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/6450/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/993/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1005/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1006/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1008/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1009/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1010/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1011/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1012/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1013/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1014/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1015/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1016/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1017/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1018/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1019/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1020/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1021/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1022/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1025/metadados
# <Response [200]>
# https://servicodados.ibge.gov.br/api/v3/agregados/1031/metadados
