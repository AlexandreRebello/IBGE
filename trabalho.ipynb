# %%
#valores para montar a base de tabelas/classificacoes/categorias/variaveis

import requests
import pandas as pd

response = requests.get('https://servicodados.ibge.gov.br/api/v3/agregados')

if response.status_code == 200:
    data = response.json()


#base de tabelas/classificacoes/categorias/variaveis

tabela = '2093'

endereco = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+tabela+'/metadados'

response = requests.get(endereco)

if response.status_code == 200:
    data = response.json()

#Catgoria x classificacao

df_categ = pd.json_normalize(data,
    record_path=['classificacoes','categorias'],
    meta=["id",["classificacoes","id"],["classificacoes","nome"]],
    meta_prefix='tabela_',
    record_prefix='categ_'
    )

#Variaveis x classificacao

df_var = pd.json_normalize(data,
    record_path=['variaveis'],
    meta=["id","nome","URL","pesquisa","assunto",["periodicidade","frequencia"],["periodicidade","inicio"],["periodicidade","fim"],["nivelTerritorial","Administrativo"]],
    meta_prefix='Tabela_',
    record_prefix='var_'
    )

if df_categ.empty:
    df = df_var
else:
    df = df_categ.merge(df_var, left_on='tabela_id',right_on='Tabela_id')
#print(df)
#valores para montar a base de tabelas/classificacoes/categorias/variaveis

import requests
import pandas as pd

response = requests.get('https://servicodados.ibge.gov.br/api/v3/agregados')

if response.status_code == 200:
    data = response.json()


#base de tabelas/classificacoes/categorias/variaveis

tabela = '1621'

endereco = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+tabela+'/metadados'

response = requests.get(endereco)

if response.status_code == 200:
    data = response.json()

#Catgoria x classificacao

df_categ1 = pd.json_normalize(data,
    record_path=['classificacoes','categorias'],
    meta=["id",["classificacoes","id"],["classificacoes","nome"]],
    meta_prefix='tabela_',
    record_prefix='categ_'
    )

#Variaveis x classificacao

df_var1 = pd.json_normalize(data,
    record_path=['variaveis'],
    meta=["id","nome","URL","pesquisa","assunto",["periodicidade","frequencia"],["periodicidade","inicio"],["periodicidade","fim"],["nivelTerritorial","Administrativo"]],
    meta_prefix='Tabela_',
    record_prefix='var_'
    )

if df_categ1.empty:
    df1 = df_var1
else:
    df1 = df_categ1.merge(df_var1, left_on='tabela_id',right_on='Tabela_id')


#df=df.append(df1)
#dfFinal = DataFrame(df1)
#dfFinal
pd.concat([df],[df1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 95
#      89     df1 = df_categ1.merge(df_var1, left_on='tabela_id',right_on='Tabela_id')
#      92 #df=df.append(df1)
#      93 #dfFinal = DataFrame(df1)
#      94 #dfFinal
# ---> 95 pd.concat([df],[df1])
#
# TypeError: concat() takes 1 positional argument but 2 were given

# %%
import requests
import pandas as pd

response = requests.get('https://servicodados.ibge.gov.br/api/v3/agregados')

if response.status_code == 200:
    data = response.json()

    resultado = pd.DataFrame({'categ_id':[], 'categ_nome':[], 'categ_unidade':[], 'categ_nivel':[], 'tabela_id':[],
       'var_id':[], 'var_nome':[], 'var_unidade':[], 'var_sumarizacao':[], 'Tabela_id':[],
       'Tabela_nome':[], 'Tabela_URL':[], 'Tabela_pesquisa':[], 'Tabela_assunto':[],
       'Tabela_periodicidade.frequencia':[], 'Tabela_periodicidade.inicio':[],
       'Tabela_periodicidade.fim':[], 'Tabela_nivelTerritorial.Administrativo':[]})


    for item in data:
        id = item['id']
        pesquisa = item['nome']
        for agregado in item['agregados']:
            id_df = agregado['id']
            nome_df = agregado['nome']
            enderecoT = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+id_df+'/metadados'
            print(enderecoT)
            responseT = requests.get(enderecoT)
            dataT = responseT.json()
            #print(dataT)
            df_categ = pd.json_normalize(dataT,
                record_path=['classificacoes','categorias'],
                meta=["id",["classificacoes","id"],["classificacoes","nome"]],
                meta_prefix='tabela_',
                record_prefix='categ_'
                )
            #print(df_categ)
                    #Variaveis x classificacao

            df_var = pd.json_normalize(dataT,
                record_path=['variaveis'],
                meta=["id","nome","URL","pesquisa","assunto",["periodicidade","frequencia"],["periodicidade","inicio"],["periodicidade","fim"],["nivelTerritorial","Administrativo"]],
                meta_prefix='Tabela_',
                record_prefix='var_'
                )
            #df_var
            if df_categ.empty:
                dfm = df_var
            else:
                dfm = df_categ.merge(df_var, left_on='tabela_id',right_on='Tabela_id')
            #print(dfm)
            resultado = pd.concat([resultado,dfm])
            
        
    print(resultado)
else:
    print(f"Request failed with status code {response.status_code}")

# %%
import requests
import pandas as pd

response = requests.get('https://servicodados.ibge.gov.br/api/v3/agregados')

if response.status_code == 200:
    data = response.json()

    resultado = pd.DataFrame({'categ_id':[], 'categ_nome':[], 'categ_unidade':[], 'categ_nivel':[], 'tabela_id':[],
       'tabela_classificacoes.id':[], 'tabela_classificacoes.nome':[],                      
       'var_id':[], 'var_nome':[], 'var_unidade':[], 'var_sumarizacao':[], 'tabela_id':[],
       'tabela_nome':[], 'tabela_URL':[], 'tabela_pesquisa':[], 'tabela_assunto':[],
       'tabela_periodicidade.frequencia':[], 'tabela_periodicidade.inicio':[],
       'tabela_periodicidade.fim':[], 'tabela_nivelTerritorial.Administrativo':[]})
    
  
    lista = pd.DataFrame({'tabela':['1621','2093','6784']})
    print(lista['tabela'])
    for item in lista['tabela']:
        tab = item
        #print(IdTabela)
        enderecoT = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+tab+'/metadados'
        print(enderecoT)
        responseT = requests.get(enderecoT)
        dataT = responseT.json()
        #print(dataT)
        df_categ = pd.json_normalize(dataT,
            record_path=['classificacoes','categorias'],
            meta=["id",["classificacoes","id"],["classificacoes","nome"]],
            meta_prefix='tabela_',
            record_prefix='categ_'
            )
       # print(df_categ)
                #Variaveis x classificacao

        df_var = pd.json_normalize(dataT,
            record_path=['variaveis'],
            meta=["id","nome","URL","pesquisa","assunto",["periodicidade","frequencia"],["periodicidade","inicio"],["periodicidade","fim"],["nivelTerritorial","Administrativo"]],
            meta_prefix='tabela_',
            record_prefix='var_'
                    )
        #nivel territorio x tabela

        df_nivel = pd.json_normalize(dataT,
            record_path=['nivelTerritorial','Administrativo'],
            meta=["id"],
            meta_prefix='tabela_',
            record_prefix='nivel_'
            )

        if df_categ.empty:
            dfm = df_var.merge(df_nivel,left_on='tabela_id',right_on='tabela_id')
        else:
            df1 = df_categ.merge(df_var, left_on='tabela_id',right_on='tabela_id')
            dfm = df1.merge(df_nivel, left_on='tabela_id',right_on='tabela_id')
        
        options = ['N1','N3','N6'] 
        df = dfm.loc[dfm['nivel_0'].isin(options)] 
        #df = df.loc[:,'tabela_id']#,'var_id','tabela_classificacoes.id','categ_id','nivel_0']]
        #print(dfm)
        #print("muda/muda/muda")
        resultado = pd.concat([resultado,df])
        resultado = resultado.loc[:,['tabela_id','var_id','tabela_classificacoes.id','categ_id','nivel_0']]
        
        resultado = [resultado[col_name].astype(str) for col_name in resultado.columns]
        #resultado['var_id'] = resultado['var_id'].astype('Int64')
        #resultado['categ_id'] = resultado['categ_id'].astype('Int64')
        resultado
    print("RESULTADO/RESULTADO/RESULTADO")    
    print(resultado)

    print(f"Request failed with status code {response.status_code}")
# Out:
# 0    1621
# 1    2093
# 2    6784
# Name: tabela, dtype: object
# https://servicodados.ibge.gov.br/api/v3/agregados/1621/metadados
# https://servicodados.ibge.gov.br/api/v3/agregados/2093/metadados
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 62
#      58 df = dfm.loc[dfm['nivel_0'].isin(options)]
#      59 #df = df.loc[:,'tabela_id']#,'var_id','tabela_classificacoes.id','categ_id','nivel_0']]
#      60 #print(dfm)
#      61 #print("muda/muda/muda")
# ---> 62 resultado = pd.concat([resultado,df])
#      63 resultado = resultado.loc[:,['tabela_id','var_id','tabela_classificacoes.id','categ_id','nivel_0']]
#      65 resultado = [resultado[col_name].astype(str) for col_name in resultado.columns]
#
# File c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\concat.py:448, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
# --> 448 ndims = self._get_ndims(objs)
#     449 sample, objs = self._get_sample_object(objs, ndims, keys, names, levels)
#     451 # Standardize axis parameter to int
#
# File c:\Users\Alexandre Rebello\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\concat.py:489, in _Concatenator._get_ndims(self, objs)
#     484     if not isinstance(obj, (ABCSeries, ABCDataFrame)):
#     485         msg = (
#     486             f"cannot concatenate object of type '{type(obj)}'; "
#     487             "only Series and DataFrame objs are valid"
#     488         )
# --> 489         raise TypeError(msg)
#     491     ndims.add(obj.ndim)
#     492 return ndims
#
# TypeError: cannot concatenate object of type '<class 'list'>'; only Series and DataFrame objs are valid

# %%
#valores para montar a base de tabelas/classificacoes/categorias/variaveis

import requests
import pandas as pd

tabela = '2093'

endereco = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+tabela+'/metadados'

response = requests.get(endereco)

if response.status_code == 200:
    data = response.json()

#Catgoria x classificacao

df_categ = pd.json_normalize(data,
    record_path=['classificacoes','categorias'],
    meta=["id"],#["classificacoes","id"],["classificacoes","nome"]],
    meta_prefix='tabela_',
    record_prefix='categ_'
    )

#Variaveis x tabela

df_var = pd.json_normalize(data,
    record_path=['variaveis'],
    meta=["id","nome","URL","pesquisa","assunto",["periodicidade","frequencia"],["periodicidade","inicio"],["periodicidade","fim"],["nivelTerritorial","Administrativo"]],
    meta_prefix='tabela_',
    record_prefix='var_'
    )

#nivel territorio x tabela

df_nivel = pd.json_normalize(data,
    record_path=['nivelTerritorial','Administrativo'],
    meta=["id"],
    meta_prefix='tabela_',
    record_prefix='nivel_'
    )

if df_categ.empty:
    df = df_var.merge(df_nivel,left_on='tabela_id',right_on='tabela_id')
else:
    df1 = df_categ.merge(df_var, left_on='tabela_id',right_on='tabela_id')
    df = df1.merge(df_nivel, left_on='tabela_id',right_on='tabela_id')



options = ['N1','N3','N6'] 
df = df.loc[df['nivel_0'].isin(options)] 

df = df.loc[:,'tabela_nome']

df
# Out:
# 1      População residente por cor ou raça, sexo, sit...
# 11     População residente por cor ou raça, sexo, sit...
# 21     População residente por cor ou raça, sexo, sit...
# 31     População residente por cor ou raça, sexo, sit...
# 41     População residente por cor ou raça, sexo, sit...
#                              ...
# 591    População residente por cor ou raça, sexo, sit...
# 601    População residente por cor ou raça, sexo, sit...
# 611    População residente por cor ou raça, sexo, sit...
# 621    População residente por cor ou raça, sexo, sit...
# 631    População residente por cor ou raça, sexo, sit...
# Name: tabela_nome, Length: 64, dtype: object

# %%
#valores para montar a base de tabelas/classificacoes/categorias/variaveis

import requests
import pandas as pd

tabela = '2093'

endereco = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+tabela+'/metadados'

response = requests.get(endereco)

if response.status_code == 200:
    data = response.json()

df_nivel = pd.json_normalize(data,
    record_path=['nivelTerritorial','Administrativo'],
    meta=["id"],
    meta_prefix='tabela_',
    record_prefix='nivel_'
    )
df_nivel
# Out:
#   nivel_0 tabela_id
# 0     N15      2093
# 1      N1      2093
# 2      N2      2093
# 3      N8      2093
# 4      N9      2093
# 5      N6      2093
# 6     N14      2093
# 7      N7      2093
# 8     N13      2093
# 9      N3      2093
