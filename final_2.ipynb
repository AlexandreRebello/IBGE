# %%
#TESTE FINAL
#lista de parametros para API

import requests
import pandas as pd
import numpy as np
import time

response = requests.get('https://servicodados.ibge.gov.br/api/v3/agregados?nivel=N6')

if response.status_code == 200:
    data = response.json()

    resultado = pd.DataFrame({'categ_id':str([]), 'categ_nome':[], 'categ_unidade':[], 'categ_nivel':[], 'tabela_id':str([]),
       'tabela_classificacoes.id':[], 'tabela_classificacoes.nome':[],                      
       'var_id':str([]), 'var_nome':[], 'var_unidade':[], 'var_sumarizacao':[], 'tabela_id':str([]),
       'Tabela_nome':[], 'Tabela_URL':[], 'Tabela_pesquisa':[], 'Tabela_assunto':[],
       'Tabela_periodicidade.frequencia':[], 'Tabela_periodicidade.inicio':[],
       'Tabela_periodicidade.fim':[], 'Tabela_nivelTerritorial.Administrativo':[]})
    
    data_list = []

    for item in data:
        id = item['id']
        pesquisa = item['nome']
        for agregado in item['agregados']:
            tabela = agregado['id']
            nome_tabela = agregado['nome']
            data_list.append([id, pesquisa, tabela, nome_tabela])
            df = pd.DataFrame(data_list, columns=['id', 'pesquisa', 'tabela', 'nome_tabela'])
    #lista = df['tabela']

    lista = pd.DataFrame({'tabela':['6784','1621','2093']})
    print(lista)
    for item in lista['tabela']:
    #for item in lista:
        tab = item
        #print(IdTabela)
        enderecoT = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+tab+'/metadados'
        print(enderecoT)
        
        segue = 0
        response = requests.get(enderecoT)
        segue = response.status_code
        print(segue)
        while segue != 200:
            response = requests.get(enderecoT)
            segue = response.status_code
            print(segue)
            print("ERRO")
            #time.sleep(2)
        # else:
        dataT = response.json()
        
        print("PASSOU")
        #print(dataT)

        #print(dataT)
        df_categ = pd.json_normalize(dataT,
            record_path=['classificacoes','categorias'],
            meta=["id",["classificacoes","id"],["classificacoes","nome"]],
            meta_prefix='tabela_',
            record_prefix='categ_',
            errors='ignore'
            )
        df_categ.to_csv("teste_categ10.csv",mode='a',header=False)
        #print(df_categ)
        #         #Variaveis x classificacao

        df_var = pd.json_normalize(dataT,
            record_path=['variaveis'],
            meta=["id"],
            meta_prefix='tabela_',
            record_prefix='var_',
            errors='ignore'
            )
        

        df_var.to_csv("teste_var10.csv",mode='a')#,header=False)

        df_tab = pd.json_normalize(dataT,
                                   
            meta=["id","nome","URL","pesquisa","assunto"],#["nivelTerritorial","Administrativo"]],
            meta_prefix='tabela_',
            record_prefix='var_',
            errors='ignore'
            )
        print(df_tab.columns)
        df_tab.to_csv("teste_tab10.csv",mode='a',sep=';', na_rep='',columns=['id','nome','URL','pesquisa','assunto','periodicidade.frequencia','periodicidade.inicio','periodicidade.fim'],header=False,index=False)
        
        #time.sleep(30)
        
        if df_categ.empty:
             dfm = df_var
        else:
            dfm = df_categ.merge(df_var, left_on='tabela_id',right_on='tabela_id')
        dfm.to_csv("teste_param10.csv",mode='a',sep=';', na_rep='',header=False)#,index=False)
        #,columns=['tabela_id','var_id','tabela_classificacoes.id','categ_id']







else:
    print(f"Request failed with status code {response.status_code}")
# Out:
#   tabela
# 0   6784
# 1   1621
# 2   2093
# https://servicodados.ibge.gov.br/api/v3/agregados/6784/metadados
# 200
# PASSOU
# Index(['id', 'nome', 'URL', 'pesquisa', 'assunto', 'variaveis',
#        'classificacoes', 'periodicidade.frequencia', 'periodicidade.inicio',
#        'periodicidade.fim', 'nivelTerritorial.Administrativo',
#        'nivelTerritorial.Especial', 'nivelTerritorial.IBGE'],
#       dtype='object')
# https://servicodados.ibge.gov.br/api/v3/agregados/1621/metadados
# 200
# PASSOU
# Index(['id', 'nome', 'URL', 'pesquisa', 'assunto', 'variaveis',
#        'classificacoes', 'periodicidade.frequencia', 'periodicidade.inicio',
#        'periodicidade.fim', 'nivelTerritorial.Administrativo',
#        'nivelTerritorial.Especial', 'nivelTerritorial.IBGE'],
#       dtype='object')
# https://servicodados.ibge.gov.br/api/v3/agregados/2093/metadados
# 200
# PASSOU
# Index(['id', 'nome', 'URL', 'pesquisa', 'assunto', 'variaveis',
#        'classificacoes', 'periodicidade.frequencia', 'periodicidade.inicio',
#        'periodicidade.fim', 'nivelTerritorial.Administrativo',
#        'nivelTerritorial.Especial', 'nivelTerritorial.IBGE'],
#       dtype='object')

# %%
# PRODUCAO

#lista de parametros para API

import requests
import pandas as pd
import numpy as np
import time

response = requests.get('https://servicodados.ibge.gov.br/api/v3/agregados?nivel=N6')

if response.status_code == 200:
    data = response.json()

    resultado = pd.DataFrame({'categ_id':str([]), 'categ_nome':[], 'categ_unidade':[], 'categ_nivel':[], 'tabela_id':str([]),
       'tabela_classificacoes.id':[], 'tabela_classificacoes.nome':[],                      
       'var_id':str([]), 'var_nome':[], 'var_unidade':[], 'var_sumarizacao':[], 'tabela_id':str([]),
       'Tabela_nome':[], 'Tabela_URL':[], 'Tabela_pesquisa':[], 'Tabela_assunto':[],
       'Tabela_periodicidade.frequencia':[], 'Tabela_periodicidade.inicio':[],
       'Tabela_periodicidade.fim':[], 'Tabela_nivelTerritorial.Administrativo':[]})
    
    data_list = []

    for item in data:
        id = item['id']
        pesquisa = item['nome']
        for agregado in item['agregados']:
            tabela = agregado['id']
            nome_tabela = agregado['nome']
            data_list.append([id, pesquisa, tabela, nome_tabela])
            df = pd.DataFrame(data_list, columns=['id', 'pesquisa', 'tabela', 'nome_tabela'])
    lista = df['tabela']

    #lista = pd.DataFrame({'tabela':['6784','1621','2093']})
    #print(lista)
    #for item in lista['tabela']:
    for item in lista:
        tab = item
        #print(IdTabela)
        enderecoT = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+tab+'/metadados'
        print(enderecoT)
        
        segue = 0
        response = requests.get(enderecoT)
        segue = response.status_code
        print(segue)
        while segue != 200:
            response = requests.get(enderecoT)
            segue = response.status_code
            print(segue)
            print("ERRO")
            #time.sleep(2)
        # else:
        dataT = response.json()
        
        print("PASSOU")

        df_categ = pd.json_normalize(dataT,
            record_path=['classificacoes','categorias'],
            meta=["id",["classificacoes","id"],["classificacoes","nome"]],
            meta_prefix='tabela_',
            record_prefix='categ_',
            errors='ignore'
            )
        df_categ.to_csv("categ_3.csv",mode='a',header=False)
   
        #         #Variaveis x classificacao

        df_var = pd.json_normalize(dataT,
            record_path=['variaveis'],
            meta=["id"],
            meta_prefix='tabela_',
            record_prefix='var_',
            errors='ignore'
            )
        
      
        df_var.to_csv("var_3.csv",mode='a')#,header=False)

        df_tab = pd.json_normalize(dataT,
                                   
            meta=["id","nome","URL","pesquisa","assunto"],#["nivelTerritorial","Administrativo"]],
            meta_prefix='tabela_',
            record_prefix='var_',
            errors='ignore'
            )
        
        df_tab.to_csv("tab_3.csv",mode='a',sep=';', na_rep='',columns=['id','nome','URL','pesquisa','assunto','periodicidade.frequencia','periodicidade.inicio','periodicidade.fim'],header=False,index=False)

        
        if df_categ.empty:
            df_var_f = pd.DataFrame({'var_id':str([]),'var_nome':[],'var_unidade':[],'var_sumarizacao':str([]),'tabela_id':str([]),'tabela_classificacoes.id':str([]),'categ_id':str([])})
            dfm = pd.concat([df_var_f,df_var])
            #print(dfm)
            #dfm.to_csv("teste_param11.csv",mode='a',sep=';', na_rep='')#,columns=['tabela_id','var_id'],header=False,index=False)
        else:
            dfm = df_categ.merge(df_var, left_on='tabela_id',right_on='tabela_id')
item in lista:
        tab = item
        #print(IdTabela)
        enderecoT = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+tab+'/metadados'
        print(enderecoT)
        
        segue = 0
        response = requests.get(enderecoT)
        segue = response.status_code
        print(segue)
        while segue != 200:
            response = requests.get(enderecoT)
            segue = response.status_code
            print(segue)
            print("ERRO")
            #time.sleep(2)
        # else:
        dataT = response.json()
        
        print("PASSOU")

        # df_categ = pd.json_normalize(dataT,
        #     record_path=['classificacoes','categorias'],
        #     meta=["id",["classificacoes","id"],["classificacoes","nome"]],
        #     meta_prefix='tabela_',
        #     record_prefix='categ_',
        #     errors='ignore'
        #     )
        # df_categ.to_csv("categ_3.csv",mode='a',header=False)
   
        #         #Variaveis x classificacao

        # df_var = pd.json_normalize(dataT,
        #     record_path=['variaveis'],
        #     meta=["id"],
        #     meta_prefix='tabela_',
        #     record_prefix='var_',
        #     errors='ignore'
        #     )
        
      
        # df_var.to_csv("var_3.csv",mode='a')#,header=False)

        df_tab = pd.json_normalize(dataT,
                                   
            meta=["id","nome","URL","pesquisa","assunto"],#["nivelTerritorial","Administrativo"]],
            meta_prefix='tabela_',
            record_prefix='var_',
            errors='ignore'
            )
        df_tab = df_tab.rename(columns={'id': 'tabela'})
        df_tab = df_tab.rename(columns={'URL': 'site'})
        df_tab = df_tab.rename(columns={'periodicidade.frequencia': 'periodicidade_frequencia'})
        df_tab = df_tab.rename(columns={'periodicidade.inicio': 'periodicidade_inicio'})
        df_tab = df_tab.rename(columns={'periodicidade.fim': 'periodicidade_fim'})
        #df_tab.drop(“column name”, axis='columns')
        df_tab2=df_tab.drop(['variaveis','classificacoes','nivelTerritorial.Administrativo','nivelTerritorial.Especial', 'nivelTerritorial.IBGE'], axis = 'columns')#,
      
        print(df_tab2.columns)
         
        # Crie a conexão com o banco de dados
        engine = create_engine('postgresql://lagoaviva:l4g04uff@54.172.235.94:5432/lagoaviva')

        # Exporte o DataFrame para uma tabela no banco de dados
        df_tab2.to_sql('tabs_api_ibge', con=engine, index=False, if_exists='append')
        #df_tab.to_csv("tab_0.csv",mode='a',sep=';', na_rep='', columns=['tabela'],header=True,index=False)
        # if df_categ.empty:
        #     df_var_f = pd.DataFrame({'var_id':str([]),'var_nome':[],'var_unidade':[],'var_sumarizacao':str([]),'tabela_id':str([]),'tabela_classificacoes.id':str([]),'categ_id':str([])})
        #     dfm = pd.concat([df_var_f,df_var])
        #     #print(dfm)
        #     #dfm.to_csv("teste_param11.csv",mode='a',sep=';', na_rep='')#,columns=['tabela_id','var_id'],header=False,index=False)
        # else:
        #     dfm = df_categ.merge(df_var, left_on='tabela_id',right_on='tabela_id')
        # dfm.to_csv("param_3.csv",mode='a',sep=';', na_rep='',columns=['tabela_id','var_id','tabela_classificacoes.id','categ_id'],header=False,index=False)

else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# https://servicodados.ibge.gov.br/api/v3/agregados/6784/metadados
# 200
# PASSOU
# Index(['tabela', 'nome', 'site', 'pesquisa', 'assunto',
#        'periodicidade_frequencia', 'periodicidade_inicio',
#        'periodicidade_fim'],
#       dtype='object')
# https://servicodados.ibge.gov.br/api/v3/agregados/1621/metadados
# 200
# PASSOU
# Index(['tabela', 'nome', 'site', 'pesquisa', 'assunto',
#        'periodicidade_frequencia', 'periodicidade_inicio',
#        'periodicidade_fim'],
#       dtype='object')
# https://servicodados.ibge.gov.br/api/v3/agregados/2093/metadados
# 200
# PASSOU
# Index(['tabela', 'nome', 'site', 'pesquisa', 'assunto',
#        'periodicidade_frequencia', 'periodicidade_inicio',
#        'periodicidade_fim'],
#       dtype='object')

# %%
# PRODUCAO TESTE SQL

#lista de parametros para API

import requests
import pandas as pd
import numpy as np
import time
#from sqlalchemy import create_engine
import io
import psycopg2

response = requests.get('https://servicodados.ibge.gov.br/api/v3/agregados?nivel=N6')

if response.status_code == 200:
    data = response.json()

    resultado = pd.DataFrame({'categ_id':str([]), 'categ_nome':[], 'categ_unidade':[], 'categ_nivel':[], 'tabela_id':str([]),
       'tabela_classificacoes.id':[], 'tabela_classificacoes.nome':[],                      
       'var_id':str([]), 'var_nome':[], 'var_unidade':[], 'var_sumarizacao':[], 'tabela_id':str([]),
       'Tabela_nome':[], 'Tabela_URL':[], 'Tabela_pesquisa':[], 'Tabela_assunto':[],
       'Tabela_periodicidade.frequencia':[], 'Tabela_periodicidade.inicio':[],
       'Tabela_periodicidade.fim':[], 'Tabela_nivelTerritorial.Administrativo':[]})
    
    conn = psycopg2.connect(
        dbname="lagoaviva",
        user="lagoaviva",
        password="l4g04uff",
        host="54.172.235.94",
        port="5432"
    )
#db.cid-uff.net
    data_list = []

    for item in data:
        id = item['id']
        pesquisa = item['nome']
        for agregado in item['agregados']:
            tabela = agregado['id']
            nome_tabela = agregado['nome']
            data_list.append([id, pesquisa, tabela, nome_tabela])
            df = pd.DataFrame(data_list, columns=['id', 'pesquisa', 'tabela', 'nome_tabela'])
    #lista = df['tabela']

    lista = pd.DataFrame({'tabela':['6784','1621','2093']})
    #print(lista)
    for item in lista['tabela']:
    #for item in lista:
        tab = item
        #print(IdTabela)
        enderecoT = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+tab+'/metadados'
        print(enderecoT)
        
        segue = 0
        response = requests.get(enderecoT)
        segue = response.status_code
        print(segue)
        while segue != 200:
            response = requests.get(enderecoT)
            segue = response.status_code
            print(segue)
            print("ERRO")
            #time.sleep(2)
        # else:
        dataT = response.json()
        
        print("PASSOU")

        # df_categ = pd.json_normalize(dataT,
        #     record_path=['classificacoes','categorias'],
        #     meta=["id",["classificacoes","id"],["classificacoes","nome"]],
        #     meta_prefix='tabela_',
        #     record_prefix='categ_',
        #     errors='ignore'
        #     )
        # df_categ.to_csv("categ_3.csv",mode='a',header=False)
   
        #         #Variaveis x classificacao

        # df_var = pd.json_normalize(dataT,
        #     record_path=['variaveis'],
        #     meta=["id"],
        #     meta_prefix='tabela_',
        #     record_prefix='var_',
        #     errors='ignore'
        #     )
        
      
        # df_var.to_csv("var_3.csv",mode='a')#,header=False)

        df_tab = pd.json_normalize(dataT,
                                   
            meta=["id","nome","URL","pesquisa","assunto"],#["nivelTerritorial","Administrativo"]],
            meta_prefix='tabela_',
            record_prefix='var_',
            errors='ignore'
            )
        df_tab = df_tab.rename(columns={'id': 'tabela'})
        # Crie um cursor
        cur = conn.cursor()

        # Crie um objeto StringIO
        sio = io.StringIO()
        sio.write(df_tab.to_csv(mode='a', columns=['tabela','nome','URL','pesquisa','assunto','periodicidade.frequencia','periodicidade.inicio','periodicidade.fim'],index=False, header=False))
        sio.seek(0)
        print(sio)
        # Copie os dados para a tabela
        cur.copy_from(sio, "api_ibge", columns=df_tab.columns, sep=',')

        # Commit as alterações
        conn.commit()

        # Feche a conexão
        conn.close()
        #print(df_tab['tabela'])

        #df_tab = df_tab.rename(columns={'id': 'tabela'})
        #df_tab.to_csv("tab_0.csv",mode='a',sep=';', na_rep='',columns=['tabela','nome','URL','pesquisa','assunto','periodicidade.frequencia','periodicidade.inicio','periodicidade.fim'],header=True,index=False)
        
        # Crie a conexão com o banco de dados
        engine = create_engine('postgresql://lagoaviva:l4g04uff@54.172.235.94:5432/lagoaviva')

        # Exporte o DataFrame para uma tabela no banco de dados
        df_tab.to_sql('teste_api_ibge', engine, index = False, if_exists='append')
        #df_tab.to_csv("tab_0.csv",mode='a',sep=';', na_rep='', columns=['tabela'],header=True,index=False)
        # if df_categ.empty:
        #     df_var_f = pd.DataFrame({'var_id':str([]),'var_nome':[],'var_unidade':[],'var_sumarizacao':str([]),'tabela_id':str([]),'tabela_classificacoes.id':str([]),'categ_id':str([])})
        #     dfm = pd.concat([df_var_f,df_var])
        #     #print(dfm)
        #     #dfm.to_csv("teste_param11.csv",mode='a',sep=';', na_rep='')#,columns=['tabela_id','var_id'],header=False,index=False)
        # else:
        #     dfm = df_categ.merge(df_var, left_on='tabela_id',right_on='tabela_id')
        # dfm.to_csv("param_3.csv",mode='a',sep=';', na_rep='',columns=['tabela_id','var_id','tabela_classificacoes.id','categ_id'],header=False,index=False)

else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# https://servicodados.ibge.gov.br/api/v3/agregados/6784/metadados
# 200
# PASSOU
# <_io.StringIO object at 0x0000022DA60A0DC0>
# ---------------------------------------------------------------------------
#
# UndefinedColumn                           Traceback (most recent call last)
#
# Cell In[49], line 108
#
#     106 print(sio)
#
#     107 # Copie os dados para a tabela
#
# --> 108 cur.copy_from(sio, "api_ibge", columns=df_tab.columns, sep=',')
#
#     110 # Commit as alterações
#
#     111 conn.commit()
#
#
#
# UndefinedColumn: column "URL" of relation "api_ibge" does not exist

# %%
from sqlalchemy import create_engine
import pandas as pd

# Crie o DataFrame
# df = pd.DataFrame({
#     'nome': ['João', 'Maria', 'Pedro'],
#     'idade': [23, 78, 22],
#     'cidade': ['Rio de Janeiro', 'São Paulo', 'Salvador']
# })

# Crie a conexão com o banco de dados
engine = create_engine('postgresql://lagoaviva:l4g04uff@db.cid-uff.net:5432/lagoaviva')

# Exporte o DataFrame para uma tabela no banco de dados
df.to_sql('nome_da_tabela', engine, if_exists='replace', index=False)
