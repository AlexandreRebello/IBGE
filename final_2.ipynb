# %%
#lista de parametros para API

import requests
import pandas as pd
import numpy as np
import time

response = requests.get('https://servicodados.ibge.gov.br/api/v3/agregados?nivel=N6')

if response.status_code == 200:
    data = response.json()

    resultado = pd.DataFrame({'categ_id':str([]), 'categ_nome':[], 'categ_unidade':[], 'categ_nivel':[], 'tabela_id':str([]),
       'tabela_classificacoes.id':[], 'tabela_classificacoes.nome':[],                      
       'var_id':str([]), 'var_nome':[], 'var_unidade':[], 'var_sumarizacao':[], 'tabela_id':str([]),
       'Tabela_nome':[], 'Tabela_URL':[], 'Tabela_pesquisa':[], 'Tabela_assunto':[],
       'Tabela_periodicidade.frequencia':[], 'Tabela_periodicidade.inicio':[],
       'Tabela_periodicidade.fim':[], 'Tabela_nivelTerritorial.Administrativo':[]})
    
    data_list = []

    for item in data:
        id = item['id']
        pesquisa = item['nome']
        for agregado in item['agregados']:
            tabela = agregado['id']
            nome_tabela = agregado['nome']
            data_list.append([id, pesquisa, tabela, nome_tabela])
            df = pd.DataFrame(data_list, columns=['id', 'pesquisa', 'tabela', 'nome_tabela'])
    #lista = df['tabela']

    lista = pd.DataFrame({'tabela':['6784','1621','2093']})
    print(lista)
    for item in lista['tabela']:
    #for item in lista:
        tab = item
        #print(IdTabela)
        enderecoT = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+tab+'/metadados'
        print(enderecoT)
        
        segue = 0
        response = requests.get(enderecoT)
        segue = response.status_code
        print(segue)
        while segue != 200:
            response = requests.get(enderecoT)
            segue = response.status_code
            print(segue)
            print("ERRO")
            #time.sleep(2)
        # else:
        dataT = response.json()
        
        print("PASSOU")
        #print(dataT)

        #print(dataT)
        df_categ = pd.json_normalize(dataT,
            record_path=['classificacoes','categorias'],
            meta=["id",["classificacoes","id"],["classificacoes","nome"]],
            meta_prefix='tabela_',
            record_prefix='categ_',
            errors='ignore'
            )
        df_categ.to_csv("teste_categ10.csv",mode='a',header=False)
        #print(df_categ)
        #         #Variaveis x classificacao

        df_var = pd.json_normalize(dataT,
            record_path=['variaveis'],
            meta=["id"],
            meta_prefix='tabela_',
            record_prefix='var_',
            errors='ignore'
            )
        

        df_var.to_csv("teste_var10.csv",mode='a')#,header=False)

        df_tab = pd.json_normalize(dataT,
                                   
            meta=["id","nome","URL","pesquisa","assunto"],#["nivelTerritorial","Administrativo"]],
            meta_prefix='tabela_',
            record_prefix='var_',
            errors='ignore'
            )
       
        df_tab.to_csv("teste_tab10.csv",mode='a',sep=';', na_rep='',columns=['id','nome','URL','pesquisa','assunto','periodicidade.frequencia','periodicidade.inicio','periodicidade.fim'],header=False,index=False)
        
        #time.sleep(30)
        
        if df_categ.empty:
             dfm = df_var
        else:
            dfm = df_categ.merge(df_var, left_on='tabela_id',right_on='tabela_id')
        dfm.to_csv("teste_param10.csv",mode='a',sep=';', na_rep='',header=False)#,index=False)
        #,columns=['tabela_id','var_id','tabela_classificacoes.id','categ_id']







else:
    print(f"Request failed with status code {response.status_code}")
# Out:
#   tabela
# 0   6784
# 1   1621
# 2   2093
# https://servicodados.ibge.gov.br/api/v3/agregados/6784/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/1621/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/2093/metadados
# 200
# PASSOU

# %%
#lista de parametros para API

import requests
import pandas as pd
import numpy as np
import time

response = requests.get('https://servicodados.ibge.gov.br/api/v3/agregados?nivel=N6')

if response.status_code == 200:
    data = response.json()

    resultado = pd.DataFrame({'categ_id':str([]), 'categ_nome':[], 'categ_unidade':[], 'categ_nivel':[], 'tabela_id':str([]),
       'tabela_classificacoes.id':[], 'tabela_classificacoes.nome':[],                      
       'var_id':str([]), 'var_nome':[], 'var_unidade':[], 'var_sumarizacao':[], 'tabela_id':str([]),
       'Tabela_nome':[], 'Tabela_URL':[], 'Tabela_pesquisa':[], 'Tabela_assunto':[],
       'Tabela_periodicidade.frequencia':[], 'Tabela_periodicidade.inicio':[],
       'Tabela_periodicidade.fim':[], 'Tabela_nivelTerritorial.Administrativo':[]})
    
    data_list = []

    for item in data:
        id = item['id']
        pesquisa = item['nome']
        for agregado in item['agregados']:
            tabela = agregado['id']
            nome_tabela = agregado['nome']
            data_list.append([id, pesquisa, tabela, nome_tabela])
            df = pd.DataFrame(data_list, columns=['id', 'pesquisa', 'tabela', 'nome_tabela'])
    #lista = df['tabela']

    lista = pd.DataFrame({'tabela':['6784','1621','2093']})
    print(lista)
    for item in lista['tabela']:
    #for item in lista:
        tab = item
        #print(IdTabela)
        enderecoT = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+tab+'/metadados'
        print(enderecoT)
        
        segue = 0
        response = requests.get(enderecoT)
        segue = response.status_code
        print(segue)
        while segue != 200:
            response = requests.get(enderecoT)
            segue = response.status_code
            print(segue)
            print("ERRO")
            #time.sleep(2)
        # else:
        dataT = response.json()
        
        print("PASSOU")
        #print(dataT)

        #print(dataT)
        df_categ = pd.json_normalize(dataT,
            record_path=['classificacoes','categorias'],
            meta=["id",["classificacoes","id"],["classificacoes","nome"]],
            meta_prefix='tabela_',
            record_prefix='categ_',
            errors='ignore'
            )
        df_categ.to_csv("teste_categ10.csv",mode='a',header=False)
        #print(df_categ)
        #         #Variaveis x classificacao

        df_var = pd.json_normalize(dataT,
            record_path=['variaveis'],
            meta=["id"],
            meta_prefix='tabela_',
            record_prefix='var_',
            errors='ignore'
            )
        
        #df_var_f = pd.DataFrame({'var_id':[],'var_nome':[],'var_unidade':[],'var_sumarizacao':[],'tabela_id':[],'tabela_classificacoes.id':[],'categ_id':[]})
        #df_var = pd.concat([df_var_f,df_var])
        df_var.to_csv("teste_var10.csv",mode='a')#,header=False)

        df_tab = pd.json_normalize(dataT,
                                   
            meta=["id","nome","URL","pesquisa","assunto"],#["nivelTerritorial","Administrativo"]],
            meta_prefix='tabela_',
            record_prefix='var_',
            errors='ignore'
            )
        
        df_tab.to_csv("teste_tab10.csv",mode='a',sep=';', na_rep='',columns=['id','nome','URL','pesquisa','assunto','periodicidade.frequencia','periodicidade.inicio','periodicidade.fim'],header=False,index=False)
        
        #time.sleep(30)
        
        if df_categ.empty:
            df_var_f = pd.DataFrame({'var_id':str([]),'var_nome':[],'var_unidade':[],'var_sumarizacao':str([]),'tabela_id':str([]),'tabela_classificacoes.id':str([]),'categ_id':str([])})
            dfm = pd.concat([df_var_f,df_var])
            print(dfm)
            #dfm.to_csv("teste_param11.csv",mode='a',sep=';', na_rep='')#,columns=['tabela_id','var_id'],header=False,index=False)
        else:
            dfm = df_categ.merge(df_var, left_on='tabela_id',right_on='tabela_id')
        dfm.to_csv("teste_param13.csv",mode='a',sep=';', na_rep='',columns=['tabela_id','var_id','tabela_classificacoes.id','categ_id'],header=False,index=False)

else:
    print(f"Request failed with status code {response.status_code}")
# Out:
#   tabela
# 0   6784
# 1   1621
# 2   2093
# https://servicodados.ibge.gov.br/api/v3/agregados/6784/metadados
# 200
# PASSOU
#   var_id                                 var_nome       var_unidade  \
# 0   9808                  PIB - valores correntes  Milhões de Reais
# 1   9809             PIB - preços do ano anterior  Milhões de Reais
# 2   9810                 PIB - variação em volume                 %
# 3   9811          PIB - deflator - variação anual                 %
# 4     93                      População residente       Mil pessoas
# 5   9812       PIB per capita - valores correntes             Reais
# 6   9813  PIB per capita - preços do ano anterior             Reais
# 7   9814      PIB per capita - variação em volume                 %
#
#   var_sumarizacao tabela_id tabela_classificacoes.id categ_id
# 0              []      6784                      NaN      NaN
# 1              []      6784                      NaN      NaN
# 2              []      6784                      NaN      NaN
# 3              []      6784                      NaN      NaN
# 4              []      6784                      NaN      NaN
# 5              []      6784                      NaN      NaN
# 6              []      6784                      NaN      NaN
# 7              []      6784                      NaN      NaN
# https://servicodados.ibge.gov.br/api/v3/agregados/1621/metadados
# 200
# PASSOU
# https://servicodados.ibge.gov.br/api/v3/agregados/2093/metadados
# 200
# PASSOU

# %%
#lista de parametros para API

import requests
import pandas as pd
import numpy as np
import time

response = requests.get('https://servicodados.ibge.gov.br/api/v3/agregados?nivel=N6')

if response.status_code == 200:
    data = response.json()

    resultado = pd.DataFrame({'categ_id':str([]), 'categ_nome':[], 'categ_unidade':[], 'categ_nivel':[], 'tabela_id':str([]),
       'tabela_classificacoes.id':[], 'tabela_classificacoes.nome':[],                      
       'var_id':str([]), 'var_nome':[], 'var_unidade':[], 'var_sumarizacao':[], 'tabela_id':str([]),
       'Tabela_nome':[], 'Tabela_URL':[], 'Tabela_pesquisa':[], 'Tabela_assunto':[],
       'Tabela_periodicidade.frequencia':[], 'Tabela_periodicidade.inicio':[],
       'Tabela_periodicidade.fim':[], 'Tabela_nivelTerritorial.Administrativo':[]})
    
    data_list = []

    for item in data:
        id = item['id']
        pesquisa = item['nome']
        for agregado in item['agregados']:
            tabela = agregado['id']
            nome_tabela = agregado['nome']
            data_list.append([id, pesquisa, tabela, nome_tabela])
            df = pd.DataFrame(data_list, columns=['id', 'pesquisa', 'tabela', 'nome_tabela'])
    #lista = df['tabela']

    lista = pd.DataFrame({'tabela':['6784','1621','2093']})
    print(lista)
    for item in lista['tabela']:
    #for item in lista:
        tab = item
        #print(IdTabela)
        enderecoT = 'https://servicodados.ibge.gov.br/api/v3/agregados/'+tab+'/metadados'
        print(enderecoT)
        
        segue = 0
        response = requests.get(enderecoT)
        segue = response.status_code
        print(segue)
        while segue != 200:
            response = requests.get(enderecoT)
            segue = response.status_code
            print(segue)
            print("ERRO")
            #time.sleep(2)
        # else:
        dataT = response.json()
        
        print("PASSOU")
        #print(dataT)

        #print(dataT)
        df_categ = pd.json_normalize(dataT,
            record_path=['classificacoes','categorias'],
            meta=["id",["classificacoes","id"],["classificacoes","nome"]],
            meta_prefix='tabela_',
            record_prefix='categ_',
            errors='ignore'
            )
        df_categ.to_csv("teste_categ10.csv",mode='a',header=False)
        #print(df_categ)
        #         #Variaveis x classificacao

        df_var = pd.json_normalize(dataT,
            record_path=['variaveis'],
            meta=["id"],
            meta_prefix='tabela_',
            record_prefix='var_',
            errors='ignore'
            )
        
        #df_var_f = pd.DataFrame({'var_id':[],'var_nome':[],'var_unidade':[],'var_sumarizacao':[],'tabela_id':[],'tabela_classificacoes.id':[],'categ_id':[]})
        #df_var = pd.concat([df_var_f,df_var])
        df_var.to_csv("teste_var10.csv",mode='a')#,header=False)

        df_tab = pd.json_normalize(dataT,
                                   
            meta=["id","nome","URL","pesquisa","assunto"],#["nivelTerritorial","Administrativo"]],
            meta_prefix='tabela_',
            record_prefix='var_',
            errors='ignore'
            )
        
        df_tab.to_csv("teste_tab10.csv",mode='a',sep=';', na_rep='',columns=['id','nome','URL','pesquisa','assunto','periodicidade.frequencia','periodicidade.inicio','periodicidade.fim'],header=False,index=False)
        
        #time.sleep(30)
        
        if df_categ.empty:
            df_var_f = pd.DataFrame({'var_id':str([]),'var_nome':[],'var_unidade':[],'var_sumarizacao':str([]),'tabela_id':str([]),'tabela_classificacoes.id':str([]),'categ_id':str([])})
            dfm = pd.concat([df_var_f,df_var])
            print(dfm)
        else:
            dfm = df_categ.merge(df_var, left_on='tabela_id',right_on='tabela_id')

        url = []
        for item in dfm:
            if 'tabela_classificacoes.id' == '':
                url = 'https://apisidra.ibge.gov.br/values/t/'+tabela_id+'/N1/all/v/'+var_id+'/p/all//h/n'
            else:
                url = 'https://apisidra.ibge.gov.br/values/t/'+tabela_id+'/N1/all/v/'+var_id+'/p/all/c'+tabela_classificacoes.id+'/'+categ_id+'/h/n'
        url 
        print(API)
        dfm.to_csv("teste_param13.csv",mode='a',sep=';', na_rep='',columns=['tabela_id','var_id','tabela_classificacoes.id','categ_id'],header=False,index=False)
        API.to_csv("teste_API1.csv",mode=a,na_rep='')


# 'https://apisidra.ibge.gov.br/values/t/'+tabela+'/'+nivel+'/v/'+variavel+'/p/all/c'+classificacao+'/'+categoria+'/h/n'



else:
    print(f"Request failed with status code {response.status_code}")
# Out:
#   tabela
# 0   6784
# 1   1621
# 2   2093
# https://servicodados.ibge.gov.br/api/v3/agregados/6784/metadados
# 200
# PASSOU
#   var_id                                 var_nome       var_unidade  \
# 0   9808                  PIB - valores correntes  Milhões de Reais
# 1   9809             PIB - preços do ano anterior  Milhões de Reais
# 2   9810                 PIB - variação em volume                 %
# 3   9811          PIB - deflator - variação anual                 %
# 4     93                      População residente       Mil pessoas
# 5   9812       PIB per capita - valores correntes             Reais
# 6   9813  PIB per capita - preços do ano anterior             Reais
# 7   9814      PIB per capita - variação em volume                 %
#
#   var_sumarizacao tabela_id tabela_classificacoes.id categ_id
# 0              []      6784                      NaN      NaN
# 1              []      6784                      NaN      NaN
# 2              []      6784                      NaN      NaN
# 3              []      6784                      NaN      NaN
# 4              []      6784                      NaN      NaN
# 5              []      6784                      NaN      NaN
# 6              []      6784                      NaN      NaN
# 7              []      6784                      NaN      NaN
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 105
#     103         url = 'https://apisidra.ibge.gov.br/values/t/'+tabela_id+'/N1/all/v/'+var_id+'/p/all//h/n'
#     104     else:
# --> 105         url = 'https://apisidra.ibge.gov.br/values/t/'+tabela_id+'/N1/all/v/'+var_id+'/p/all/c'+tabela_classificacoes.id+'/'+categ_id+'/h/n'
#     106 print(API)
#     107 dfm.to_csv("teste_param13.csv",mode='a',sep=';', na_rep='',columns=['tabela_id','var_id','tabela_classificacoes.id','categ_id'],header=False,index=False)
#
# NameError: name 'tabela_id' is not defined
